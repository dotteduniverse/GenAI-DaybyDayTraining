# %% [markdown]
# # Solutions – Day 41 (Example)
#
# Here is an example design doc for a project called **“Sketch-to-Interior Designer”**.

# %%
example_doc = """
# Sketch-to-Interior Designer

## One‑line description
A web app that turns a rough sketch of a room into a realistic interior design image using ControlNet + Stable Diffusion.

## Problem statement
Interior design ideation is time‑consuming. Non‑designers struggle to visualise changes. This tool allows anyone to draw a simple layout and instantly see a styled version.

## Target users
Homeowners, renters, interior design hobbyists.

## Core features
1. Upload a sketch or draw online.
2. Choose a style (modern, rustic, etc.).
3. Generate an AI‑rendered room.
4. Download or share result.

## Tech stack
- Models: Stable Diffusion 1.5 + ControlNet (canny/scribble), BLIP for optional captioning.
- Libraries: Diffusers, Gradio (UI), Hugging Face Spaces (deployment).

## Data sources
No custom dataset – uses pre‑trained ControlNet. Optionally, collect user sketches for fine‑tuning later.

## Evaluation plan
- Usability: time to generate first image (< 10 sec).
- Quality: user rating (1‑5) on 10 generated images.
- Engagement: number of generations per session.

## Timeline
Day 42: Collect 5 sample sketches for testing.
Day 43: Gradio prototype with basic sketch canvas.
Day 44: Optimise inference (use vLLM? not applicable; use torch.compile and half‑precision).
Day 45: Deploy to HF Spaces.
Day 46: Add LangSmith logging of prompts/outputs.
Day 47: Add simple API key (optional).
Day 48: Write blog post about the project.
Day 49: Test with 5 users, fix bugs.
Day 50: Record demo video.
"""
print(example_doc)

with open("EXAMPLE_DESIGN.md", "w") as f:
    f.write(example_doc)
print("Saved example design doc.")

# %%
# Exercise 5: Risk assessment example
risks = [
    ("ControlNet memory usage", "Use FP16 and CPU offload"),
    ("Slow generation on free Spaces", "Use smaller model or queue"),
    ("Sketch quality too low", "Add edge detection preprocessing")
]
for risk, mitigation in risks:
    print(f"Risk: {risk} -> Mitigation: {mitigation}")
