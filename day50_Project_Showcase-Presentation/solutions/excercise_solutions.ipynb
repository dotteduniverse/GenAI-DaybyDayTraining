# %% [markdown]
# # Solutions – Day 50 (Example Submission)

# %%
# Exercise 1: Video recording tips
video_tips = """
- Use a quiet environment.
- Speak clearly and slowly.
- Zoom in on important UI elements.
- If you make a mistake, pause and restart that sentence (edit later).
- Add captions for accessibility (YouTube auto‑captions).
"""
print(video_tips)

# %%
# Exercise 2: Presentation checklist
presentation_check = """
- [ ] Title slide with name and date.
- [ ] Problem slide (relatable).
- [ ] Solution + screenshot.
- [ ] Architecture diagram (use Mermaid or draw.io).
- [ ] Results with numbers or quotes.
- [ ] Lessons learned (bullet points).
- [ ] Future work.
- [ ] Q&A slide.
"""
print(presentation_check)

# %%
# Exercise 3: Final repo structure example
repo_structure = """
my-capstone/
├── app.py
├── requirements.txt
├── README.md
├── .env.example
├── notebooks/
│   └── exploration.ipynb
├── src/
│   ├── model.py
│   ├── utils.py
├── tests/
│   └── test_model.py
└── assets/
    ├── demo.gif
    └── architecture.png
"""
print(repo_structure)

# %%
# Exercise 4: Submission email template
email_template = """
Subject: Capstone Project Submission – [Your Name]

Dear [Mentor/Teacher],

I have completed my 50‑day GenAI capstone project. Below are the deliverables:

- GitHub repo: [URL]
- Live demo: [URL]
- Demo video: [URL]
- Blog post: [URL]

Thank you for the guidance!

Best,
[Your Name]
"""
print(email_template)

# %%
# Exercise 5: 60‑second lightning talk script example
lightning = """
"I built a sketch‑to‑interior design tool. Upload a rough room sketch, choose a style, and AI generates a realistic render.
It uses ControlNet with Stable Diffusion, served via Gradio on Hugging Face Spaces.
Key challenge was latency – solved with FP16 and vLLM.
Check the live demo and GitHub link in the chat. Thanks!"
"""
print(lightning)
