# %% [markdown]
# # Solutions – Day 48

# %%
# Exercise 1: Example snippet of a completed template (partial)
example_post = """
# From Sketch to Interior: Building a Design Tool with ControlNet

## Introduction
Have you ever wanted to visualise a room design but can't afford an interior designer? I built a web app that turns rough sketches into realistic room renders using Stable Diffusion + ControlNet.

[Live Demo](https://huggingface.co/spaces/myusername/sketch-to-interior)

## Architecture
The app uses:
- ControlNet (canny) to condition on edge maps.
- Stable Diffusion 1.5 for generation.
- Gradio for the interface.

## Code snippet
```python
pipe = StableDiffusionControlNetPipeline.from_pretrained(...)
output = pipe(prompt, image=control_image).images[0]
```

## Challenges
**Latency**: Using half-precision (FP16) reduced generation time from 15s to 8s.
**Sketch quality**: Added Canny preprocessing to enhance edges.

## Results
![demo](demo.gif)

## Future work
Add style selection (modern, rustic) and export to 3D.
"""
print(example_post)

# %%
# Exercise 2: Using AI to improve the draft (mock)
# After calling improve_writing(my_draft), you might get:
improved = "I developed a RAG chatbot leveraging FAISS and GPT-3.5. It achieves high accuracy. The code is publicly available on GitHub."
print("Improved version:", improved)

# %%
# Exercise 3: Command to create GIF (requires ffmpeg)
# ffmpeg -i demo.mp4 -vf "fps=10,scale=800:-1" -loop 0 demo.gif
print("Run this in terminal to convert screen recording to GIF")

# %%
# Exercise 5: SEO keywords example
keywords = ["RAG chatbot tutorial", "LangChain guide", "GPT-3.5 summarisation"]
print("Suggested keywords for the post:", keywords)
