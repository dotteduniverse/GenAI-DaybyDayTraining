# %% [markdown]
# # Solutions – Day 45

# %%
# Exercise 1: Script to create Space via huggingface_hub (optional)
# from huggingface_hub import create_repo, upload_folder
# create_repo("my-space", repo_type="space", space_sdk="gradio")
# upload_folder("my-space", folder_path="./my_hf_space", repo_type="space")
print("Manual creation on HF website is easier for beginners.")

# %%
# Exercise 3: Use local model in Spaces (app.py example with Phi-2)
phi_app = """
import gradio as gr
from transformers import AutoModelForCausalLM, AutoTokenizer

model = AutoModelForCausalLM.from_pretrained("microsoft/phi-2", device_map="auto")
tokenizer = AutoTokenizer.from_pretrained("microsoft/phi-2")

def generate(prompt):
    inputs = tokenizer(prompt, return_tensors="pt")
    outputs = model.generate(**inputs, max_new_tokens=100)
    return tokenizer.decode(outputs[0])

gr.Interface(fn=generate, inputs="text", outputs="text").launch()
"""
print(phi_app)

# %%
# Exercise 4: Using secrets in HF Spaces
# In app.py:
# import os
# OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
# Then go to your Space Settings → Repository Secrets → Add OPENAI_API_KEY.

# %%
# Exercise 5: Replicate cog.yaml example
cog_yaml = """
build:
  gpu: true
  python_version: "3.10"
  python_packages:
    - torch
    - transformers
predict: "predict.py:Predictor"
"""
print(cog_yaml)
print("Then create predict.py with a Predictor class. See Replicate docs.")
